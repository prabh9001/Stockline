# %%
import pandas as pd
import numpy as ny
import matplotlib.pyplot as plt 
import plotly.graph_objs as go
import yfinance as yf
import mplfinance as mpf
import datetime

#for offline plotting
from plotly.offline import download_plotlyjs,init_notebook_mode,iplot, plot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# Python Data Cleaning using commands

# %%
# Get the current date
end = datetime.date.today()

# Set the start date to 10 years ago
start = end- datetime.timedelta(days=365*14)

df = yf.Ticker('ONGC.NS')

df.actions
df.cashflow
df.balance_sheet
df.insider_roster_holders
df.major_holders

df = yf.download('ONGC.NS', start, end)
# Out:
# c:\Users\WAHEGURU JI\AppData\Local\Programs\Python\Python39\lib\site-packages\yfinance\utils.py:775: FutureWarning:
#
# The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#
# c:\Users\WAHEGURU JI\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\dtypes\cast.py:1057: RuntimeWarning:
#
# invalid value encountered in cast
#
# c:\Users\WAHEGURU JI\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\dtypes\cast.py:1081: RuntimeWarning:
#
# invalid value encountered in cast
#
# c:\Users\WAHEGURU JI\AppData\Local\Programs\Python\Python39\lib\site-packages\yfinance\utils.py:775: FutureWarning:
#
# The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#
# [*********************100%%**********************]  1 of 1 completed

# %%
df.shape
# Out:
# (3454, 6)

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df = df.reset_index()
df['Date'] = pd.to_datetime(df['Date'])
# Set 'date_column' as the index
df.set_index('Date', inplace=True)

# %%
df.head(1000)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-03-19  176.333328  177.166672  174.191666  176.141663   94.891846
# 2010-03-22  175.666672  178.199997  174.433334  176.524994   95.098328
# 2010-03-23  177.041672  179.008331  176.383331  178.208328   96.005203
# 2010-03-25  178.166672  178.333328  175.091660  176.108337   94.873856
# 2010-03-26  176.666672  180.666672  176.666672  179.983337   96.961441
# ...                ...         ...         ...         ...         ...
# 2014-03-25  206.000000  214.266663  204.166672  213.266663  130.329773
# 2014-03-26  213.666672  218.533340  213.333328  216.866669  132.529770
# 2014-03-27  214.266663  222.666672  212.033340  220.666672  136.637161
# 2014-03-28  221.333328  222.600006  218.300003  219.600006  135.976685
# 2014-03-31  219.033340  223.600006  210.800003  212.466660  131.559723
#
#               Volume
# Date
# 2010-03-19   4986024
# 2010-03-22   4146252
# 2010-03-23   5168454
# 2010-03-25   6617802
# 2010-03-26   7182120
# ...              ...
# 2014-03-25  10734699
# 2014-03-26   5695686
# 2014-03-27  14993080
# 2014-03-28   3774826
# 2014-03-31   6561028
#
# [1000 rows x 6 columns]

# %%
df.tail(1000)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-03-03   90.900002   94.000000   89.650002   93.349998   69.410118
# 2020-03-04   94.199997   94.900002   90.699997   92.800003   69.001183
# 2020-03-05   93.349998   94.400002   92.000000   92.599998   68.852470
# 2020-03-06   89.500000   91.500000   87.650002   88.500000   65.803917
# 2020-03-09   82.150002   82.500000   74.000000   74.550003   55.431435
# ...                ...         ...         ...         ...         ...
# 2024-03-07  280.250000  284.350006  277.250000  278.100006  278.100006
# 2024-03-11  278.100006  280.500000  273.200012  274.000000  274.000000
# 2024-03-12  274.000000  275.600006  269.049988  270.399994  270.399994
# 2024-03-13  270.799988  271.000000  252.750000  255.350006  255.350006
# 2024-03-14  252.500000  264.350006  251.199997  263.250000  263.250000
#
#               Volume
# Date
# 2020-03-03  24098468
# 2020-03-04  22998427
# 2020-03-05  16357817
# 2020-03-06  17823038
# 2020-03-09  86655504
# ...              ...
# 2024-03-07  11386963
# 2024-03-11  10684598
# 2024-03-12  13780189
# 2024-03-13  20079496
# 2024-03-14  21404057
#
# [1000 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3454 entries, 2010-03-19 to 2024-03-14
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3454 non-null   float64
#  1   High       3454 non-null   float64
#  2   Low        3454 non-null   float64
#  3   Close      3454 non-null   float64
#  4   Adj Close  3454 non-null   float64
#  5   Volume     3454 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 188.9 KB

# %% [markdown]
# Note:No null value in data set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3454 entries, 2010-03-19 to 2024-03-14
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3454 non-null   float64
#  1   High       3454 non-null   float64
#  2   Low        3454 non-null   float64
#  3   Close      3454 non-null   float64
#  4   Adj Close  3454 non-null   float64
#  5   Volume     3454 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 188.9 KB

# %%
#to remove null vaues from column
df.dropna(inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#now our rows were deleted which have the null values
df.shape
# Out:
# (3454, 6)

# %%
# to see the number of columns name
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %% [markdown]
# Exploring the data analysis

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3454.000000  3454.000000  3454.000000  3454.000000  3454.000000
# mean    171.211675   173.449679   168.671941   170.897336   117.852767
# std      43.170519    43.713928    42.523427    43.078671    30.857264
# min      59.400002    63.000000    50.000000    60.000000    44.612827
# 25%     146.362503   148.262501   144.262501   146.370838   100.172853
# 50%     174.149994   176.158333   171.500000   174.050003   114.072327
# 75%     193.933334   196.000000   191.137497   193.249996   130.861191
# max     313.333344   314.566681   298.666656   310.433319   283.750000
#
#              Volume
# count  3.454000e+03
# mean   1.133637e+07
# std    1.281291e+07
# min    0.000000e+00
# 25%    4.714708e+06
# 50%    7.342644e+06
# 75%    1.275818e+07
# max    1.780948e+08

# %%
d=df[['High','Low','Open','Close']]
fig=mpf.plot(d,type='candle')
# Out:
# c:\Users\WAHEGURU JI\AppData\Local\Programs\Python\Python39\lib\site-packages\mplfinance\_arg_validators.py:84: UserWarning:
#
#
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================

# %%
d=df[['High','Low','Open','Close']]
fig=mpf.plot(df,type='candle',volume=True)
# Out:
# c:\Users\WAHEGURU JI\AppData\Local\Programs\Python\Python39\lib\site-packages\mplfinance\_arg_validators.py:84: UserWarning:
#
#
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================

# %% [markdown]
# Note: Candle Kind graph to show the datset

# %%
ma100 = df.Close.rolling(100).mean()
fig=plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100)

# %%
ma100 = df.Close.rolling(100).mean()
ma200 = df.Close.rolling(200).mean()
fig=plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100)
plt.plot(ma200)

# %%
df = df.reset_index()
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
#Setting the layout of the graph
layout = go.Layout(
    title='Stock prices',
    xaxis=dict(
        title='Year',
        titlefont=dict(
            family='Courier New,monospace',
            size=18,
            color='black'
        )
    ),
yaxis=dict(
        title='Price',
        titlefont=dict(
            family='Courier New,monospace',
            size=18,
            color='black'
        )
        )
        )
Adani_data=[{'x':df['Date'],'y':df['Close']}]
plot= go.Figure(data=Adani_data,layout=layout)

# %%
#to plot the graph in offline
iplot(plot)
# Out:
# <div>                            <div id="3b18d738-dc27-4c16-8689-818b46df4aa2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b18d738-dc27-4c16-8689-818b46df4aa2")) {                    Plotly.newPlot(                        "3b18d738-dc27-4c16-8689-818b46df4aa2",                        [{"x":["2010-03-19T00:00:00","2010-03-22T00:00:00","2010-03-23T00:00:00","2010-03-25T00:00:00","2010-03-26T00:00:00","2010-03-29T00:00:00","2010-03-30T00:00:00","2010-03-31T00:00:00","2010-04-01T00:00:00","2010-04-05T00:00:00","2010-04-06T00:00:00","2010-04-07T00:00:00","2010-04-08T00:00:00","2010-04-09T00:00:00","2010-04-12T00:00:00","2010-04-13T00:00:00","2010-04-15T00:00:00","2010-04-16T00:00:00","2010-04-19T00:00:00","2010-04-20T00:00:00","2010-04-21T00:00:00","2010-04-22T00:00:00","2010-04-23T00:00:00","2010-04-26T00:00:00","2010-04-27T00:00:00","2010-04-28T00:00:00","2010-04-29T00:00:00","2010-04-30T00:00:00","2010-05-03T00:00:00","2010-05-04T00:00:00","2010-05-05T00:00:00","2010-05-06T00:00:00","2010-05-07T00:00:00","2010-05-10T00:00:00","2010-05-11T00:00:00","2010-05-12T00:00:00","2010-05-13T00:00:00","2010-05-14T00:00:00","2010-05-17T00:00:00","2010-05-18T00:00:00","2010-05-19T00:00:00","2010-05-20T00:00:00","2010-05-21T00:00:00","2010-05-24T00:00:00","2010-05-25T00:00:00","2010-05-26T00:00:00","2010-05-27T00:00:00","2010-05-28T00:00:00","2010-05-31T00:00:00","2010-06-01T00:00:00","2010-06-02T00:00:00","2010-06-03T00:00:00","2010-06-04T00:00:00","2010-06-07T00:00:00","2010-06-08T00:00:00","2010-06-09T00:00:00","2010-06-10T00:00:00","2010-06-11T00:00:00","2010-06-14T00:00:00","2010-06-15T00:00:00","2010-06-16T00:00:00","2010-06-17T00:00:00","2010-06-18T00:00:00","2010-06-21T00:00:00","2010-06-22T00:00:00","2010-06-23T00:00:00","2010-06-24T00:00:00","2010-06-25T00:00:00","2010-06-28T00:00:00","2010-06-29T00:00:00","2010-06-30T00:00:00","2010-07-01T00:00:00","2010-07-02T00:00:00","2010-07-05T00:00:00","2010-07-06T00:00:00","2010-07-07T00:00:00","2010-07-08T00:00:00","2010-07-09T00:00:00","2010-07-12T00:00:00","2010-07-13T00:00:00","2010-07-14T00:00:00","2010-07-15T00:00:00","2010-07-16T00:00:00","2010-07-19T00:00:00","2010-07-20T00:00:00","2010-07-21T00:00:00","2010-07-22T00:00:00","2010-07-23T00:00:00","2010-07-26T00:00:00","2010-07-27T00:00:00","2010-07-28T00:00:00","2010-07-29T00:00:00","2010-07-30T00:00:00","2010-08-02T00:00:00","2010-08-03T00:00:00","2010-08-04T00:00:00","2010-08-05T00:00:00","2010-08-06T00:00:00","2010-08-09T00:00:00","2010-08-10T00:00:00","2010-08-11T00:00:00","2010-08-12T00:00:00","2010-08-13T00:00:00","2010-08-16T00:00:00","2010-08-17T00:00:00","2010-08-18T00:00:00","2010-08-19T00:00:00","2010-08-20T00:00:00","2010-08-23T00:00:00","2010-08-24T00:00:00","2010-08-25T00:00:00","2010-08-26T00:00:00","2010-08-27T00:00:00","2010-08-30T00:00:00","2010-08-31T00:00:00","2010-09-01T00:00:00","2010-09-02T00:00:00","2010-09-03T00:00:00","2010-09-06T00:00:00","2010-09-07T00:00:00","2010-09-08T00:00:00","2010-09-09T00:00:00","2010-09-13T00:00:00","2010-09-14T00:00:00","2010-09-15T00:00:00","2010-09-16T00:00:00","2010-09-17T00:00:00","2010-09-20T00:00:00","2010-09-21T00:00:00","2010-09-22T00:00:00","2010-09-23T00:00:00","2010-09-24T00:00:00","2010-09-27T00:00:00","2010-09-28T00:00:00","2010-09-29T00:00:00","2010-09-30T00:00:00","2010-10-01T00:00:00","2010-10-04T00:00:00","2010-10-05T00:00:00","2010-10-06T00:00:00","2010-10-07T00:00:00","2010-10-08T00:00:00","2010-10-11T00:00:00","2010-10-12T00:00:00","2010-10-13T00:00:00","2010-10-14T00:00:00","2010-10-15T00:00:00","2010-10-18T00:00:00","2010-10-19T00:00:00","2010-10-20T00:00:00","2010-10-21T00:00:00","2010-10-22T00:00:00","2010-10-25T00:00:00","2010-10-26T00:00:00","2010-10-27T00:00:00","2010-10-28T00:00:00","2010-10-29T00:00:00","2010-11- ...

# %% [markdown]
# Note:It shows the stock price of Adni ports

# %% [markdown]
# Now building the linear regression model

# %%
#build the regresssion model
from sklearn.model_selection import train_test_split

#for preprocssing
from sklearn.preprocessing import StandardScaler

#for model evaulation and for accuracy
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score

# %%
#now we can split the data into training set and testing set
from numpy import reshape

X=ny.array(df.index).reshape(-1, 1)
Y=df['Close']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=101)
scaler= StandardScaler().fit(X_train)

# %% [markdown]
# Imporing Linear Model

# %%
from sklearn.linear_model import LinearRegression

# %%
#creating a linear model
lm=LinearRegression()
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
#plot actual and predicted values to train dataset
trace0=go.Scatter(
    x=X_train.T[0],
    y=Y_train,
    mode='markers',
    name= 'Actual'
    )
trace1=go.Scatter(
    x=X_train.T[0],
    y=lm.predict(X_train).T,
    mode='lines',
    name= 'Predicted'
    )
data=[trace0,trace1]
layout.xaxis.title.text = 'Day'
plot2=go.Figure(data=data, layout=layout)

# %%
iplot(plot2)
# Out:
# <div>                            <div id="dc315ae3-d3aa-481e-af8d-ed285d23e09d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc315ae3-d3aa-481e-af8d-ed285d23e09d")) {                    Plotly.newPlot(                        "dc315ae3-d3aa-481e-af8d-ed285d23e09d",                        [{"mode":"markers","name":"Actual","x":[1196,764,1591,1826,1157,3383,2541,2826,2907,739,653,618,1124,3064,2116,971,2591,3263,1170,2061,36,487,2092,1212,2475,1481,309,1626,336,1655,149,2972,1160,2291,2882,2063,1695,1543,873,659,1787,2925,2672,2828,2415,288,3314,37,1508,2687,1468,1060,69,1683,352,1598,3227,445,2712,2852,630,1849,1545,574,1669,2023,286,2376,3317,2973,2597,1525,3038,1635,1321,1945,2010,2851,929,2749,1958,495,2703,809,2946,1708,2334,3163,2831,3433,3261,1362,2125,914,2645,1147,1712,1001,1055,2346,3045,303,650,860,503,2352,3176,2883,1833,3042,28,864,369,2721,3183,1113,24,652,2510,2574,614,1462,1596,2877,3200,331,1186,1447,2616,1296,3091,2673,1209,1026,1832,1448,1737,1277,1289,425,1103,1250,338,2709,51,964,506,1150,194,1861,1271,1998,2242,656,762,150,899,3140,161,1219,543,1004,507,35,1387,862,1886,122,1792,2205,2976,1483,970,1809,3288,3249,2097,224,3278,2617,3015,396,1145,1254,2171,542,1798,2752,685,734,42,2314,780,210,2966,1331,2958,3359,1016,2790,3193,2375,3309,3024,969,3005,2625,761,3189,3426,2671,492,3043,1510,280,89,881,273,2110,2427,535,130,381,2777,1146,590,486,3446,1086,2128,308,2046,2840,225,2899,2527,2770,19,1630,1469,168,1979,452,1193,2167,3141,2226,713,674,2293,2622,3271,2392,1342,2898,925,488,2085,1075,640,3431,2656,2784,1921,3334,1346,2246,406,800,1437,531,1999,1899,2113,1771,564,1047,714,3405,1006,1827,875,2465,1846,722,207,2350,1276,109,2401,774,1700,2688,1989,1682,417,2142,847,2764,3416,1091,2279,2521,1649,2174,3168,1666,2143,913,2222,2608,1249,3378,743,577,206,2094,710,2227,2679,1864,3210,1102,567,2017,2842,124,1822,1506,1672,185,1925,3361,467,2437,2037,1142,628,2650,601,2256,949,337,976,2592,226,1507,3329,1646,2730,187,545,783,533,1294,2345,2783,1476,1928,1349,1892,1477,197,1089,612,3341,706,265,1740,2507,1650,30,1550,1062,1638,2383,1350,824,2868,2182,3445,898,450,2667,345,3415,1323,1671,1773,1877,2443,213,110,1315,412,1473,897,641,2422,2884,1853,514,100,26,1941,3062,363,1936,2194,1073,1255,1494,3252,1542,817,1691,176,815,1214,1765,1152,333,3296,2249,3376,1306,2795,1000,3132,1735,127,2450,2965,3238,2508,3173,2016,2408,2001,433,201,326,1474,2372,1676,1023,1769,830,85,281,3207,624,2969,3393,1183,3104,236,2520,3327,377,1443,397,1171,1070,1247,356,2607,1987,98,2179,1404,879,2164,1686,3208,1199,1983,1871,2008,96,2079,700,1141,1072,2606,745,2893,2631,850,1066,3275,1208,509,2659,1850,1470,637,3034,3379,1835,3384,1201,642,2468,2565,1570,1997,1797,2829,2281,3204,3202,2815,1241,846,2849,2250,1182,2394,2067,2430,3413,171,3295,2424,538,1200,2332,638,3023,1371,782,2320,1988,0,2743,1754,895,347,1279,1095,295,418,306,1082,2395,3027,2796,211,1137,3371,1488,3390,2936,584,2213,2854,1597,1536,1955,835,1675,2651,1077,2568,1336,1248,3226,2963,658,2676,822,2151,2558,582,2462,217,2441,1965,34,2980,767,1867,3026,680,2988,930,2335,2309,3286,1731,2834,249,719,2670,1472,2701,179,1836,2916,594,1837,2211,3069,3085,3109,1518,1319,1914,2231,621,123,1087,3375,2134,2691,1751,1966,1226,2081,3106,2928,1450,681,263,1533,696,1049,3392,2668,2523,447,1681,199,3013,3319,41,407,1386,580,2014,3152,3277,2173,1957,2564,1410,3322,2129,955,2518,2087,3203,1920,2519,3121,2066,1302,1972,2727,557,1684,935,2957,852,2683,2232,16,3093,1694,718,3161,67,537,1403,3154,408,2436,933,1907,2135,3304,2438,791,2731,395,1418,2156,1431,1325,807,456,282,2694,1834,2489,3440,88,315,3060,414,1745,1673,2138,2157,2923,1939,1297,3117,2970,314,1964,1114,1027,1710,1084,3169,2148,1243,1587,2082,2210,63,3201,2737,3418,1993,3073,485,3284,3244,871,2302,31 ...

# %% [markdown]
# Note:Blue dots Represent the actual value and the orange line represent the predicted values

# %%
#Cal score of final model evaluation
score=f'''
{'Metric'.ljust(10)}{'Train'.center(20)}{'Test'.center(20)}
{'r2_score'.ljust(10)}{r2_score(Y_train,lm.predict(X_train))}\t{r2_score(Y_test,lm.predict(X_test))}
{'MSE'.ljust(10)}{mse(Y_train,lm.predict(X_train))}\t{mse(Y_test,lm.predict(X_test))}
'''

print(score)
# Out:
# Metric           Train                Test
# r2_score  0.23371616645092808	0.27943602117442023
# MSE       1453.7795396175545	1266.082696469959
